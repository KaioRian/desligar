# %% [markdown]
# <a href="https://colab.research.google.com/github/KaioRian/desligar/blob/main/BotLittleLemon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pytelegrambotapi
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.1/243.1 kB 3.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pytelegrambotapi: filename=pyTelegramBotAPI-4.14.0-py3-none-any.whl size=215250 sha256=1cca8eea6076ac16652be7658d969c7b2a765ba248ab0b2843e8c99a7efff622
#   Stored in directory: /root/.cache/pip/wheels/25/51/2d/24b40a366c85c37928d5aa36ddf257e5a79fad25e1ecd11b2c
# Successfully built pytelegrambotapi
# ...

# %%
import telebot

CHAVE_API = "6986842994:AAFjCcMId-4tkHeUGgMhnUKqmfOXk2ExhQw"

bot = telebot.TeleBot(CHAVE_API)

# %%
@bot.message_handler(commands=["Fritas"])
def Fritas(mensagem):
    bot.send_message(mensagem.chat.id, "Seu pedido foi realizado!")

@bot.message_handler(commands=["Pastelzinho"])
def Pastelzinho(mensagem):
    bot.send_message(mensagem.chat.id, "Seu pedido foi realizado!")

@bot.message_handler(commands=["Bruschettas"])
def Bruschettas(mensagem):
    bot.send_message(mensagem.chat.id, "Seu pedido foi realizado!")

@bot.message_handler(commands=["Entrada"])
def Entrada(mensagem):
    texto = """
    Qual seu pedido? (Clique em uma opção)
    /Bruschettas Bruschettas
    /Pastelzinho Pastelzinho
    /Fritas Fritas com quijo e bacon"""
    bot.send_message(mensagem.chat.id, texto)

@bot.message_handler(commands=["Bolonhesa"])
def Bolonhesa(mensagem):
    bot.send_message(mensagem.chat.id, "Seu pedido foi realizado!")

@bot.message_handler(commands=["Bife"])
def Bife(mensagem):
    bot.send_message(mensagem.chat.id, "Seu pedido foi realizado!")

@bot.message_handler(commands=["Risoto"])
def Risoto(mensagem):
    bot.send_message(mensagem.chat.id, "Seu pedido foi realizado!")

@bot.message_handler(commands=["Principal"])
def Principal(mensagem):
    texto = """
    Qual seu pedido? (Clique em uma opção)
    /Risoto Risoto
    /Bife Bife a cavalo
    /Bolonhesa Bolonhesa"""
    bot.send_message(mensagem.chat.id, texto)

@bot.message_handler(commands=["Trufa"])
def Trufa(mensagem):
    bot.send_message(mensagem.chat.id, "Seu pedido foi realizado!")

@bot.message_handler(commands=["Petit"])
def Petit(mensagem):
    bot.send_message(mensagem.chat.id, "Seu pedido foi realizado!")

@bot.message_handler(commands=["Pudim"])
def Pudim(mensagem):
    bot.send_message(mensagem.chat.id, "Seu pedido foi realizado!")

@bot.message_handler(commands=["Sobremesa"])
def Sobremesa(mensagem):
    texto = """
    Qual seu pedido? (Clique em uma opção)
    /Pudim Pudim
    /Petit Petit Gateu
    /Trufa Trufa"""
    bot.send_message(mensagem.chat.id, texto)

@bot.message_handler(commands=["Vinho"])
def Vinho(mensagem):
    bot.send_message(mensagem.chat.id, "Seu pedido foi realizado!")

@bot.message_handler(commands=["Suco"])
def Suco(mensagem):
    bot.send_message(mensagem.chat.id, "Seu pedido foi realizado!")

@bot.message_handler(commands=["Coca"])
def Coca(mensagem):
    bot.send_message(mensagem.chat.id, "Seu pedido foi realizado!")

@bot.message_handler(commands=["Bebidas"])
def Bebidas(mensagem):
    texto = """
    Qual seu pedido? (Clique em uma opção)
    /Coca Coca-Cola
    /Suco Suco de Laraja
    /Vinho Vinho Seco"""
    bot.send_message(mensagem.chat.id, texto)

@bot.message_handler(commands=["Pedido"])
def Pedido(mensagem):
    texto = """
    Qual seu pedido? (Clique em uma opção)
    /Entrada Entrada
    /Principal Prato Principal
    /Sobremesa Sobremesa
    /Bebidas Bedidas"""
    bot.send_message(mensagem.chat.id, texto)


@bot.message_handler(commands=["Reclamacoes"])
def Reclamacoes(mensagem):
    bot.send_message(mensagem.chat.id, "Deixe sua reclamação:")

@bot.message_handler(commands=["Cinco"])
def Cinco(mensagem):
    bot.send_message(mensagem.chat.id, "Obrigado pelo feedback!")

@bot.message_handler(commands=["Quatro"])
def Quatro(mensagem):
    bot.send_message(mensagem.chat.id, "Obrigado pelo feedback!")

@bot.message_handler(commands=["Três"])
def Três(mensagem):
    bot.send_message(mensagem.chat.id, "Obrigado pelo feedback!")

@bot.message_handler(commands=["Dois"])
def Dois(mensagem):
    bot.send_message(mensagem.chat.id, "Obrigado pelo feedback!")

@bot.message_handler(commands=["Um"])
def Um(mensagem):
    bot.send_message(mensagem.chat.id, "Obrigado pelo feedback!")

@bot.message_handler(commands=["Avalie"])
def Avalie(mensagem):
    texto = """
    Avalie-nos (Clique no item):
    /Um 1 Estrela
    /Dois 2 Estrelas
    /Três 3 Estrelas
    /Quatro 4 Estrelas
    /Cinco 5 Estrelas"""
    bot.send_message(mensagem.chat.id, texto)

@bot.message_handler(commands=["Suporte"])
def Suporte(mensagem):
    bot.send_message(mensagem.chat.id, "Deixe aqui sua dúvida")

def verificar(mensagem):
    return True

@bot.message_handler(func=verificar)
def responder(mensagem):
    texto = """
    Escolha uma opção para continuar (Clique no item):
     /Pedido Fazer um pedido
     /Reclamacoes Reclamações
     /Avalie Avalie
     /Suporte Suporte
Selecione uma das opções"""
    bot.reply_to(mensagem, texto)

bot.polling()
